# %% [markdown]
# # 実際にトラックとドローンを動かすにあたりクラスの導入と動作確認
# ●ドローンの初期変数(番号, 航続距離, 充電時間, 飛行距離, 速度)
#
# 残りの、(目的地、飛行時間、充電時間、とかはその都度決めとけばいい)

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
cords = np.array([(0,0),(1,0),(1,1),(0,1)])
pos = {i:cords[i] for i in range(4)}
plt.scatter(cords[:,0], cords[:,1])
plt.show()

# %% [markdown]
# # ドローンは直線上を動くが目的地着いたら変数を変えて方向変換してほしい。
#
# ●あと、本番では帰り道のコーディングがやばい(その都度車に対して接近するようなコーディングにする？or目的地を最初に求める？)
#
# →一旦車に近づくコードにする

# %%
class drone:
    def __init__(self, id_, dep_time, speed, depNum, destNum): #startPoint, destination, time_outというのを後でagent変数として加える
        self.id_ = id_
        self.dep_corr = pos[depNum]
        self.dest_corr = pos[destNum]
        self.position = self.dep_corr
        self.speed = speed
        self.delivered = False
        self.working = True # 車に戻ったらこれを切る
        
    def procede(self):
        dist = np.linalg.norm(self.dest_corr - self.position)
        #print("dest=",self.dest_corr)
        #print("car_corr=",car_corr)
        if dist < self.speed:
            self.position = self.dest_corr
            #print("drone_pos=", self.position)
            #print("arrived")
            if not self.delivered:
                self.delivered = True
            if self.delivered and (np.linalg.norm(car_corr - self.position) < self.speed):
                self.working = False
                #print("a")
            #print("destination=", self.dest_corr)
            
        else:
            vector = self.dest_corr - self.position
            e = vector / np.linalg.norm(vector + 1e-10)
            self.position = self.position + e * self.speed
            #print("drone_pos=", self.position)
    def work(self):
        if self.delivered:
            self.dest_corr = car_corr
        self.procede()
            
    def action(self):
        if self.working:
            self.work()
    
class car:
    def __init__(self, id_, dep_time, speed, routeList, centroids, pos): #
        self.id_ = id_
        self.routeList = routeList
        self.centroids = centroids
        self.pos = pos
        self.depNum = 0 # この番号はあくまでもルートリストの中のindexであることに注意！！
        self.destNum = 1  # この番号はあくまでもルートリストの中のindexであることに注意！！
        self.dep_corr = self.pos[routeList[0]]
        self.dest_corr = self.pos[routeList[1]]
        self.position = self.dep_corr
        self.speed = speed
        self.visitNodes = len(self.routeList)
        self.centroidNum = 0
        self.finished = False
        
    def procede(self):
        #print("dest=",self.routeList[self.destNum])
        #print("dep=",self.routeList[self.depNum])
        dist = np.linalg.norm(self.dest_corr - self.position )
        #print(dist)
        if dist < self.speed: # 次のステップで近づけたら、という意味
            self.position = self.dest_corr
            self.changeDirection()
            #print("car arrived")
        else:
            vector = (self.dest_corr - self.position)  # まだ目標まで遠いときは、の意味
            e = vector / np.linalg.norm(vector + 1e-10)
            self.position = self.position + e * self.speed
            #print("car_pos=", self.position)
    
    def count(self): #次の重心についてしまったけどドローンが全員帰ってきてないときは待つ
        count_ = sum([1 for drone in droneSet if drone.working])
        if count_ == 0:
            print("All On the car")
        #print("DroneNum=",2- count_)
        return count_
    
    def changeDirection(self): # Centroidまでは何も考えず進む、centroidでは必ずdroneが全部来るまで待つ
        self.depNum = self.destNum # 出発点を変更
        if routeList[self.depNum] in centroids and self.count() != 0: # これが0だったら全員車に戻ってる
                print("Waiting for Drone")
                
        else: # RouteListがいっぱいになったらお役御免
            if self.destNum >= len(self.routeList) - 1:
                self.finished = True
            else:
                self.destNum += 1
                self.dest_corr = self.pos[self.routeList[self.destNum]]
                print("car_dest=",self.dest_corr, "destNum=",self.routeList[self.destNum], "num=",self.destNum)

# %% [markdown]
# # 以下、シミュレーションのひな型

# %%
droneSet = [drone(1, 0, 0.1, 0, 2), drone(1, 0, 0.1, 0, 1)]
len(droneSet)

a = (np.array([drone.position for drone in droneSet]).flatten())
routeList = [0,3,2,1]
centroids = [ 2]
trajectory = np.zeros((0,4))
car_trajectory = np.zeros((0,2))
car_1 = car(1, 0, 0.07,  routeList, centroids, pos)



for time in range(40):
    print("time=", time)
    car_1.count()
    if time == 0:
       pass
    else:
        car_1.procede()
        car_corr = car_1.position
        [drone.action() for drone in droneSet]
    a = (np.array([droneSet[i].position for i in range(2)]).flatten())
    trajectory = np.append(trajectory, np.array([a]), axis = 0)
    car_trajectory = np.append(car_trajectory, np.array([car_1.position]), axis = 0)
    print(a, car_1.position)
    """plt.figure()
    plt.scatter(trajectory[time,0],trajectory[time,1],c = "b")
    plt.scatter(trajectory[time,2],trajectory[time,3],c = "green")
    plt.scatter(car_trajectory[time,0],car_trajectory[time,1],c = "red")
    plt.plot(trajectory[:,0],trajectory[:,1],c = "b")
    plt.plot(trajectory[:,2],trajectory[:,3],c = "green")
    plt.plot(car_trajectory[:,0],car_trajectory[:,1], c = "red")
    plt.xlim([-0.2,1.1]), plt.ylim([-0.2,1.1])
    plt.savefig("forMovie/time="+str(time)+"_test.png")
    plt.close()"""

    #print()
#print(car_trajectory)
plt.plot(trajectory[:,0],trajectory[:,1],c = "b")
plt.plot(trajectory[:,2],trajectory[:,3],c = "green")
plt.plot(car_trajectory[:,0],car_trajectory[:,1], c = "red")
plt.xlim([-0.2,1.1]), plt.ylim([-0.2,1.1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-4caa012bf946> in <module>()
# ----> 1 droneSet = [drone(1, 0, 0.1, 0, 2), drone(1, 0, 0.1, 0, 1)]
#       2 len(droneSet)
#       3
#       4 a = (np.array([drone.position for drone in droneSet]).flatten())
#       5 routeList = [0,3,2,1]
#
# <ipython-input-2-2335ca81cea3> in __init__(self, id_, dep_time, speed, depNum, destNum)
#       2     def __init__(self, id_, dep_time, speed, depNum, destNum): #startPoint, destination, time_outというのを後でagent変数として加える
#       3         self.id_ = id_
# ----> 4         self.dep_corr = pos[depNum]
#       5         self.dest_corr = pos[destNum]
#       6         self.position = self.dep_corr
#
# KeyError: 0

# %% [markdown]
# # ここで今一度グラフのインポート

# %%
import pandas as pd
import pickle
def pickle_load(path):
    with open(path, mode='rb') as f:
        data = pickle.load(f)
        return data

df = pd.read_csv("networkData.csv")
pos = pickle_load("positionDict.pickle")
df1, df2, df3 = df["START_NODE"], df["END_NODE"], df["LENGTH"]
#range(len(list(pos)))
df2 = df2.replace(list(pos),range(len(list(pos))))
df1 = df1.replace(list(pos),range(len(list(pos))))
edges = np.concatenate([np.array([df1]), np.array([df2]), np.array([df3])], axis = 0).T
coords = df.values[:,1:3]
posRename = {}
# ndarrayの情報を「頂点:(x,y)」という値(辞書)に変換する
for i in range(len(coords) ):
    if i != 0 and (coords[i][0], coords[i][1]) == (coords[i-1][0], coords[i-1][1]):
        pass
    else:
        posRename[int(df1[i])] = (coords[i][0], coords[i][1])
np.savetxt("edge_weight.txt", edges, fmt = '%d')

posOpt = pickle_load("GraphOfDeliverly/positionOpt.pickle")
EdgeOpts = pickle_load("GraphOfDeliverly/EdgeOpt.pickle")
centroids = np.loadtxt("GraphOfDeliverly/centroids.csv",  delimiter = ",")
coors = np.loadtxt("GraphOfDeliverly/deliverlyPlaces.csv", delimiter = ",")
Gopt = nx.Graph()
Gopt.add_edges_from(EdgeOpts)
G2 = nx.read_weighted_edgelist("edge_weight.txt", nodetype = int)
nx.draw(G2, posRename, node_size = 1, node_color = "b", edge_color="gray", width=1)
#nx.draw(Gopt, posOpt, node_size = 8, node_color = "blue", edge_color="Blue", width=3,)

centroids = np.zeros((0,3))
nx.draw(G2, posRename, node_size = 0, node_color = "b", edge_color="gray", width=1,)
N_CLUST = 10
cl = ["r", "magenta", "g","orange", "brown", "violet", "black", "cyan", "mistyrose"]
for cluster in range(N_CLUST):
    data_ = coors[np.where(coors[:,2] == cluster)]
    centroid_ = np.mean(data_, axis = 0)
    #print(centroid_)
    centroids = np.append(centroids, np.array([centroid_]), axis = 0)
    plt.scatter(data_[:,0], data_[:,1], marker = ".", c =cl[int(cluster%9)], s = 40)
    plt.scatter(centroid_[0], centroid_[1], marker = "*", c =cl[int(cluster%9)], s = 80, alpha = 0.6)

routeList = list(posOpt.keys())
print("len=",len(routeList))
posOpt = {key: np.array([posOpt[key]]) for key in routeList}
print(routeList)
centroids = [ 2]
trajectory = np.zeros((0,4))
car_trajectory = np.zeros((0,2))
car_1 = car(1, 0, 1e-3,  routeList, centroids, posOpt)
for time in range(220):
    print("time=", time)
    car_1.count()
    if time == 0:
        pass
    elif car_1.finished:
        print("finished")
        break
    else:   
        car_1.procede()
        car_corr = car_1.position
    car_trajectory = np.append(car_trajectory, np.array(car_1.position), axis = 0)
    #print(car_1.position)
    """plt.figure()
    plt.scatter(trajectory[time,0],trajectory[time,1],c = "b")
    plt.scatter(trajectory[time,2],trajectory[time,3],c = "green")
    plt.scatter(car_trajectory[time,0],car_trajectory[time,1],c = "red")
    plt.plot(trajectory[:,0],trajectory[:,1],c = "b")
    plt.plot(trajectory[:,2],trajectory[:,3],c = "green")
    plt.plot(car_trajectory[:,0],car_trajectory[:,1], c = "red")
    plt.xlim([-0.2,1.1]), plt.ylim([-0.2,1.1])
    plt.savefig("forMovie/time="+str(time)+"_test.png")
    plt.close()"""

    #print()
#print(car_trajectory)
#plt.scatter(posOpt[212][:,0],posOpt[212][1], marker = "h",c = "green", )
plt.plot(car_trajectory[:,0],car_trajectory[:,1], c = "red", linewidth = 2)
#plt.xlim([-0.2,1.1]), plt.ylim([-0.2,1.1])

plt.show()
# Out:
# C:\Users\akihiro\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# C:\Users\akihiro\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:522: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cb.is_string_like(edge_color) \
# C:\Users\akihiro\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:543: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if cb.is_string_like(edge_color) or len(edge_color) == 1:
# C:\Users\akihiro\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# C:\Users\akihiro\Anaconda3\lib\site-packages\matplotlib\__init__.py:911: MatplotlibDeprecationWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   mplDeprecation)
# C:\Users\akihiro\Anaconda3\lib\site-packages\matplotlib\rcsetup.py:156: MatplotlibDeprecationWarning: axes.hold is deprecated, will be removed in 3.0
#   mplDeprecation)
# len= 139
# [139.0, 163.0, 212.0, 235.0, 239.0, 253.0, 258.0, 290.0, 282.0, 288.0, 276.0, 247.0, 203.0, 197.0, 180.0, 173.0, 132.0, 110.0, 90.0, 80.0, 88.0, 79.0, 78.0, 73.0, 62.0, 52.0, 56.0, 111.0, 129.0, 108.0, 118.0, 125.0, 166.0, 174.0, 184.0, 207.0, 219.0, 237.0, 245.0, 261.0, 272.0, 333.0, 334.0, 344.0, 360.0, 361.0, 388.0, 403.0, 410.0, 417.0, 437.0, 449.0, 461.0, 486.0, 492.0, 532.0, 541.0, 539.0, 538.0, 556.0, 552.0, 605.0, 596.0, 635.0, 650.0, 674.0, 694.0, 667.0, 678.0, 698.0, 681.0, 713.0, 727.0, 745.0, 787.0, 762.0, 866.0, 895.0, 843.0, 922.0, 908.0, 1044.0, 1076.0, 1094.0, 1103.0, 1107.0, 1154.0, 1182.0, 1183.0, 1180.0, 1179.0, 1178.0, 1225.0, 1159.0, 1153.0, 1115.0, 1095.0, 1056.0, 1086.0, 1073.0, 1071.0, 1060.0, 1048.0, 1008.0, 1014.0, 989.0, 972.0, 947.0, 955.0, 973.0, 982.0, 994.0, 1000.0, 999.0, 1032.0, 1030.0, 1029.0, 1047.0, 1063.0, 1077.0, 1099.0, 1069.0, 1034.0, 976.0, 953.0, 917.0, 870.0, 828.0, 816.0, 802.0, 772.0, 743.0, 711.0, 656.0, 0.0, 638.0, 624.0, 622.0, 613.0]
# time= 0
# All On the car
# time= 1
# All On the car
# time= 2
# All On the car
# car_dest= [[0.52127174 0.06279005]] destNum= 212.0 num= 2
# time= 3
# All On the car
# time= 4
# All On the car
# time= 5
# All On the car
# car_dest= [[0.52123433 0.06438283]] destNum= 235.0 num= 3
# time= 6
# All On the car
# time= 7
# All On the car
# car_dest= [[0.52121412 0.0645651 ]] destNum= 239.0 num= 4
# time= 8
# All On the car
# car_dest= [[0.52069482 0.0651737 ]] destNum= 253.0 num= 5
# time= 9
# All On the car
# car_dest= [[0.52089371 0.06566195]] destNum= 258.0 num= 6
# time= 10
# All On the car
# car_dest= [[0.5216224  0.06715622]] destNum= 290.0 num= 7
# time= 11
# All On the car
# time= 12
# All On the car
# car_dest= [[0.52208821 0.06710855]] destNum= 282.0 num= 8
# time= 13
# All On the car
# car_dest= [[0.52221882 0.06724951]] destNum= 288.0 num= 9
# time= 14
# All On the car
# car_dest= [[0.52220888 0.06653211]] destNum= 276.0 num= 10
# time= 15
# All On the car
# car_dest= [[0.52241038 0.06486245]] destNum= 247.0 num= 11
# time= 16
# All On the car
# time= 17
# All On the car
# car_dest= [[0.52375433 0.06235398]] destNum= 203.0 num= 12
# time= 18
# All On the car
# time= 19
# All On the car
# time= 20
# All On the car
# car_dest= [[0.5240307  0.06193083]] destNum= 197.0 num= 13
# time= 21
# All On the car
# car_dest= [[0.5244562  0.06121702]] destNum= 180.0 num= 14
# time= 22
# All On the car
# car_dest= [[0.52482257 0.06063443]] destNum= 173.0 num= 15
# time= 23
# All On the car
# car_dest= [[0.5260353  0.05870562]] destNum= 132.0 num= 16
# time= 24
# All On the car
# time= 25
# All On the car
# time= 26
# All On the car
# car_dest= [[0.52744032 0.05644741]] destNum= 110.0 num= 17
# time= 27
# All On the car
# time= 28
# All On the car
# time= 29
# All On the car
# car_dest= [[0.52793355 0.05573351]] destNum= 90.0 num= 18
# time= 30
# All On the car
# car_dest= [[0.5281705  0.05540163]] destNum= 80.0 num= 19
# time= 31
# All On the car
# car_dest= [[0.52826854 0.05567889]] destNum= 88.0 num= 20
# time= 32
# All On the car
# car_dest= [[0.52881922 0.05528983]] destNum= 79.0 num= 21
# time= 33
# All On the car
# car_dest= [[0.52883504 0.05512169]] destNum= 78.0 num= 22
# time= 34
# All On the car
# car_dest= [[0.52887928 0.054833  ]] destNum= 73.0 num= 23
# time= 35
# All On the car
# car_dest= [[0.52920559 0.0543987 ]] destNum= 62.0 num= 24
# time= 36
# All On the car
# car_dest= [[0.52944371 0.05416051]] destNum= 52.0 num= 25
# time= 37
# All On the car
# car_dest= [[0.52945393 0.05418939]] destNum= 56.0 num= 26
# time= 38
# All On the car
# car_dest= [[0.5302439  0.05651912]] destNum= 111.0 num= 27
# time= 39
# All On the car
# time= 40
# All On the car
# time= 41
# All On the car
# car_dest= [[0.53098043 0.05846167]] destNum= 129.0 num= 28
# time= 42
# All On the car
# time= 43
# All On the car
# time= 44
# All On the car
# car_dest= [[0.52853635 0.05633372]] destNum= 108.0 num= 29
# time= 45
# All On the car
# time= 46
# All On the car
# time= 47
# All On the car
# time= 48
# All On the car
# car_dest= [[0.52836006 0.05694482]] destNum= 118.0 num= 30
# time= 49
# All On the car
# car_dest= [[0.52797736 0.05822443]] destNum= 125.0 num= 31
# time= 50
# All On the car
# time= 51
# All On the car
# car_dest= [[0.5273678  0.06023776]] destNum= 166.0 num= 32
# time= 52
# All On the car
# time= 53
# All On the car
# time= 54
# All On the car
# car_dest= [[0.52723174 0.06063463]] destNum= 174.0 num= 33
# time= 55
# All On the car
# car_dest= [[0.52694436 0.06140032]] destNum= 184.0 num= 34
# time= 56
# All On the car
# car_dest= [[0.52658026 0.06259651]] destNum= 207.0 num= 35
# time= 57
# All On the car
# time= 58
# All On the car
# car_dest= [[0.52645837 0.06310838]] destNum= 219.0 num= 36
# time= 59
# All On the car
# car_dest= [[0.52611557 0.06449607]] destNum= 237.0 num= 37
# time= 60
# All On the car
# time= 61
# All On the car
# car_dest= [[0.52600046 0.06482842]] destNum= 245.0 num= 38
# time= 62
# All On the car
# car_dest= [[0.52551761 0.06573345]] destNum= 261.0 num= 39
# time= 63
# All On the car
# time= 64
# All On the car
# car_dest= [[0.52522697 0.06626462]] destNum= 272.0 num= 40
# time= 65
# All On the car
# car_dest= [[0.52396308 0.06961683]] destNum= 333.0 num= 41
# time= 66
# All On the car
# time= 67
# All On the car
# time= 68
# All On the car
# time= 69
# All On the car
# car_dest= [[0.52395116 0.06965707]] destNum= 334.0 num= 42
# time= 70
# All On the car
# car_dest= [[0.52446715 0.07019214]] destNum= 344.0 num= 43
# time= 71
# All On the car
# car_dest= [[0.524356   0.07084286]] destNum= 360.0 num= 44
# time= 72
# All On the car
# car_dest= [[0.52433632 0.07096575]] destNum= 361.0 num= 45
# time= 73
# All On the car
# car_dest= [[0.52562307 0.07240422]] destNum= 388.0 num= 46
# time= 74
# All On the car
# time= 75
# All On the car
# car_dest= [[0.52542362 0.07301245]] destNum= 403.0 num= 47
# time= 76
# All On the car
# car_dest= [[0.52530243 0.07334737]] destNum= 410.0 num= 48
# time= 77
# All On the car
# car_dest= [[0.52520461 0.07361985]] destNum= 417.0 num= 49
# time= 78
# All On the car
# car_dest= [[0.52487019 0.0746209 ]] destNum= 437.0 num= 50
# time= 79
# All On the car
# time= 80
# All On the car
# car_dest= [[0.52461921 0.07524493]] destNum= 449.0 num= 51
# time= 81
# All On the car
# car_dest= [[0.52447267 0.0756205 ]] destNum= 461.0 num= 52
# time= 82
# All On the car
# car_dest= [[0.52499068 0.07647328]] destNum= 486.0 num= 53
# time= 83
# All On the car
# car_dest= [[0.5249185  0.07684164]] destNum= 492.0 num= 54
# time= 84
# All On the car
# car_dest= [[0.52478666 0.07843131]] destNum= 532.0 num= 55
# time= 85
# All On the car
# time= 86
# All On the car
# car_dest= [[0.52426863 0.07881825]] destNum= 541.0 num= 56
# time= 87
# All On the car
# car_dest= [[0.52423125 0.078608  ]] destNum= 539.0 num= 57
# time= 88
# All On the car
# car_dest= [[0.52412188 0.07806195]] destNum= 538.0 num= 58
# time= 89
# All On the car
# car_dest= [[0.52442219 0.0796363 ]] destNum= 556.0 num= 59
# time= 90
# All On the car
# time= 91
# All On the car
# car_dest= [[0.52463518 0.07946964]] destNum= 552.0 num= 60
# time= 92
# All On the car
# car_dest= [[0.52554258 0.08168748]] destNum= 605.0 num= 61
# time= 93
# All On the car
# time= 94
# All On the car
# time= 95
# All On the car
# car_dest= [[0.52562026 0.08141847]] destNum= 596.0 num= 62
# time= 96
# All On the car
# car_dest= [[0.52669791 0.08266631]] destNum= 635.0 num= 63
# time= 97
# All On the car
# time= 98
# All On the car
# car_dest= [[0.52649191 0.08337021]] destNum= 650.0 num= 64
# time= 99
# All On the car
# car_dest= [[0.52732001 0.08451511]] destNum= 674.0 num= 65
# time= 100
# All On the car
# time= 101
# All On the car
# car_dest= [[0.52780322 0.08527205]] destNum= 694.0 num= 66
# time= 102
# All On the car
# car_dest= [[0.52872785 0.08415793]] destNum= 667.0 num= 67
# time= 103
# All On the car
# time= 104
# All On the car
# car_dest= [[0.52892376 0.08483203]] destNum= 678.0 num= 68
# time= 105
# All On the car
# car_dest= [[0.52907816 0.08534252]] destNum= 698.0 num= 69
# time= 106
# All On the car
# car_dest= [[0.52945765 0.08491299]] destNum= 681.0 num= 70
# time= 107
# All On the car
# car_dest= [[0.5291548  0.08577343]] destNum= 713.0 num= 71
# time= 108
# All On the car
# car_dest= [[0.5304239 0.0860303]] destNum= 727.0 num= 72
# time= 109
# All On the car
# time= 110
# All On the car
# car_dest= [[0.53013031 0.08669262]] destNum= 745.0 num= 73
# time= 111
# All On the car
# car_dest= [[0.53012221 0.08771716]] destNum= 787.0 num= 74
# time= 112
# All On the car
# time= 113
# All On the car
# car_dest= [[0.5305846  0.08704435]] destNum= 762.0 num= 75
# time= 114
# All On the car
# car_dest= [[0.53130626 0.08988125]] destNum= 866.0 num= 76
# time= 115
# All On the car
# time= 116
# All On the car
# time= 117
# All On the car
# car_dest= [[0.53175681 0.0904815 ]] destNum= 895.0 num= 77
# time= 118
# All On the car
# car_dest= [[0.53196513 0.08913467]] destNum= 843.0 num= 78
# time= 119
# All On the car
# time= 120
# All On the car
# car_dest= [[0.53216866 0.09091977]] destNum= 922.0 num= 79
# time= 121
# All On the car
# time= 122
# All On the car
# car_dest= [[0.53171703 0.09073871]] destNum= 908.0 num= 80
# time= 123
# All On the car
# car_dest= [[0.53105295 0.09434767]] destNum= 1044.0 num= 81
# time= 124
# All On the car
# time= 125
# All On the car
# time= 126
# All On the car
# time= 127
# All On the car
# car_dest= [[0.53037669 0.09518739]] destNum= 1076.0 num= 82
# time= 128
# All On the car
# time= 129
# All On the car
# car_dest= [[0.52986384 0.09573063]] destNum= 1094.0 num= 83
# time= 130
# All On the car
# car_dest= [[0.52963812 0.09599694]] destNum= 1103.0 num= 84
# time= 131
# All On the car
# car_dest= [[0.52956418 0.0960818 ]] destNum= 1107.0 num= 85
# time= 132
# All On the car
# car_dest= [[0.52856705 0.09712633]] destNum= 1154.0 num= 86
# time= 133
# All On the car
# time= 134
# All On the car
# car_dest= [[0.52787142 0.09753255]] destNum= 1182.0 num= 87
# time= 135
# All On the car
# car_dest= [[0.52715949 0.09754289]] destNum= 1183.0 num= 88
# time= 136
# All On the car
# car_dest= [[0.52680096 0.09750301]] destNum= 1180.0 num= 89
# time= 137
# All On the car
# car_dest= [[0.52675812 0.09750098]] destNum= 1179.0 num= 90
# time= 138
# All On the car
# car_dest= [[0.52639165 0.0974839 ]] destNum= 1178.0 num= 91
# time= 139
# All On the car
# car_dest= [[0.52517974 0.09849148]] destNum= 1225.0 num= 92
# time= 140
# All On the car
# time= 141
# All On the car
# car_dest= [[0.5245234  0.09718687]] destNum= 1159.0 num= 93
# time= 142
# All On the car
# time= 143
# All On the car
# car_dest= [[0.5240978  0.09711102]] destNum= 1153.0 num= 94
# time= 144
# All On the car
# car_dest= [[0.52347653 0.0962191 ]] destNum= 1115.0 num= 95
# time= 145
# All On the car
# time= 146
# All On the car
# car_dest= [[0.52318308 0.09581442]] destNum= 1095.0 num= 96
# time= 147
# All On the car
# car_dest= [[0.52253808 0.09482772]] destNum= 1056.0 num= 97
# time= 148
# All On the car
# time= 149
# All On the car
# car_dest= [[0.52174207 0.09552393]] destNum= 1086.0 num= 98
# time= 150
# All On the car
# time= 151
# All On the car
# car_dest= [[0.52149217 0.09514834]] destNum= 1073.0 num= 99
# time= 152
# All On the car
# car_dest= [[0.5214558  0.09508982]] destNum= 1071.0 num= 100
# time= 153
# All On the car
# car_dest= [[0.52128609 0.09487405]] destNum= 1060.0 num= 101
# time= 154
# All On the car
# car_dest= [[0.52102894 0.09447091]] destNum= 1048.0 num= 102
# time= 155
# All On the car
# car_dest= [[0.5201426  0.09331645]] destNum= 1008.0 num= 103
# time= 156
# All On the car
# time= 157
# All On the car
# car_dest= [[0.51989922 0.0934057 ]] destNum= 1014.0 num= 104
# time= 158
# All On the car
# car_dest= [[0.51925921 0.09285612]] destNum= 989.0 num= 105
# time= 159
# All On the car
# car_dest= [[0.5186826 0.0923607]] destNum= 972.0 num= 106
# time= 160
# All On the car
# car_dest= [[0.51794015 0.09178192]] destNum= 947.0 num= 107
# time= 161
# All On the car
# car_dest= [[0.51791968 0.09191744]] destNum= 955.0 num= 108
# time= 162
# All On the car
# car_dest= [[0.51669122 0.09241177]] destNum= 973.0 num= 109
# time= 163
# All On the car
# time= 164
# All On the car
# car_dest= [[0.51606589 0.09274408]] destNum= 982.0 num= 110
# time= 165
# All On the car
# car_dest= [[0.51553236 0.09291712]] destNum= 994.0 num= 111
# time= 166
# All On the car
# car_dest= [[0.51482869 0.09307249]] destNum= 1000.0 num= 112
# time= 167
# All On the car
# car_dest= [[0.51425851 0.0930531 ]] destNum= 999.0 num= 113
# time= 168
# All On the car
# car_dest= [[0.51408647 0.09398353]] destNum= 1032.0 num= 114
# time= 169
# All On the car
# car_dest= [[0.51350371 0.09390825]] destNum= 1030.0 num= 115
# time= 170
# All On the car
# car_dest= [[0.51290413 0.09393723]] destNum= 1029.0 num= 116
# time= 171
# All On the car
# car_dest= [[0.51258753 0.09442366]] destNum= 1047.0 num= 117
# time= 172
# All On the car
# car_dest= [[0.5123389  0.09496909]] destNum= 1063.0 num= 118
# time= 173
# All On the car
# car_dest= [[0.51223326 0.09526368]] destNum= 1077.0 num= 119
# time= 174
# All On the car
# car_dest= [[0.51177101 0.09594332]] destNum= 1099.0 num= 120
# time= 175
# All On the car
# car_dest= [[0.5116482  0.09502721]] destNum= 1069.0 num= 121
# time= 176
# All On the car
# car_dest= [[0.51134503 0.09400517]] destNum= 1034.0 num= 122
# time= 177
# All On the car
# time= 178
# All On the car
# car_dest= [[0.51074272 0.09259937]] destNum= 976.0 num= 123
# time= 179
# All On the car
# time= 180
# All On the car
# car_dest= [[0.51090516 0.09186228]] destNum= 953.0 num= 124
# time= 181
# All On the car
# car_dest= [[0.51115066 0.0908536 ]] destNum= 917.0 num= 125
# time= 182
# All On the car
# time= 183
# All On the car
# car_dest= [[0.51138957 0.0899216 ]] destNum= 870.0 num= 126
# time= 184
# All On the car
# car_dest= [[0.51170616 0.08868681]] destNum= 828.0 num= 127
# time= 185
# All On the car
# time= 186
# All On the car
# car_dest= [[0.51161267 0.08844668]] destNum= 816.0 num= 128
# time= 187
# All On the car
# car_dest= [[0.51162023 0.08806552]] destNum= 802.0 num= 129
# time= 188
# All On the car
# car_dest= [[0.5116493  0.08734196]] destNum= 772.0 num= 130
# time= 189
# All On the car
# car_dest= [[0.51161861 0.08664395]] destNum= 743.0 num= 131
# time= 190
# All On the car
# car_dest= [[0.51161477 0.08570574]] destNum= 711.0 num= 132
# time= 191
# All On the car
# car_dest= [[0.51222133 0.0835379 ]] destNum= 656.0 num= 133
# time= 192
# All On the car
# time= 193
# All On the car
# time= 194
# All On the car
# car_dest= [[0.5117808  0.08268412]] destNum= 0.0 num= 134
# time= 195
# All On the car
# car_dest= [[0.51176999 0.08266306]] destNum= 638.0 num= 135
# time= 196
# All On the car
# car_dest= [[0.51154421 0.08222364]] destNum= 624.0 num= 136
# time= 197
# All On the car
# car_dest= [[0.5115105  0.08216053]] destNum= 622.0 num= 137
# time= 198
# All On the car
# car_dest= [[0.51140439 0.08196019]] destNum= 613.0 num= 138
# time= 199
# All On the car
# time= 200
# All On the car
# finished
