# %% [markdown]
# # 実際にトラックとドローンを動かすにあたりクラスの導入と動作確認
# ●ドローンの初期変数(番号, 航続距離, 充電時間, 飛行距離, 速度)
#
# 残りの、(目的地、飛行時間、充電時間、とかはその都度決めとけばいい)

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
cords = np.array([(0,0),(1,0),(1,1),(0,1)])
pos = {i:cords[i] for i in range(4)}
plt.scatter(cords[:,0], cords[:,1])
plt.show()

# %% [markdown]
# # ドローンは直線上を動くが目的地着いたら変数を変えて方向変換してほしい。
#
# ●あと、本番では帰り道のコーディングがやばい(その都度車に対して接近するようなコーディングにする？or目的地を最初に求める？)
#
# →一旦車に近づくコードにする

# %%
class drone:
    def __init__(self, id_, dep_time, speed, depNum, destNum): #startPoint, destination, time_outというのを後でagent変数として加える
        self.id_ = id_
        self.dep_corr = pos[depNum]
        self.dest_corr = pos[destNum]
        self.position = self.dep_corr
        self.speed = speed
        self.delivered = False
        self.working = True # 車に戻ったらこれを切る
        
    def procede(self):
        dist = np.linalg.norm(self.dest_corr - self.position)
        #print("dest=",self.dest_corr)
        print("car_corr=",car_corr)
        if dist < self.speed:
            self.position = self.dest_corr
            print("drone_pos=", self.position)
            print("arrived")
            if not self.delivered:
                self.delivered = True
            if self.delivered and (np.linalg.norm(car_corr - self.position) < self.speed):
                self.working = False
                print("a")
            print("destination=", self.dest_corr)
            
        else:
            vector = self.dest_corr - self.position
            e = vector / np.linalg.norm(vector + 1e-10)
            self.position = self.position + e * self.speed
            print("drone_pos=", self.position)
    def work(self):
        if self.delivered:
            self.dest_corr = car_corr
        self.procede()
            
    def action(self):
        if self.working:
            self.work()
    
class car:
    def __init__(self, id_, dep_time, speed, routeList, centroids): #
        self.id_ = id_
        self.routeList = routeList
        self.centroids = centroids
        self.dep_corr = pos[routeList[0]]
        self.dest_corr = pos[routeList[1]]
        self.position = self.dep_corr
        self.speed = speed
        
    def procede(self):
        dist = np.linalg.norm(self.dest_corr - self.position)
        #print(dist)
        if dist <= self.speed:
            self.position = self.dest_corr
            self.dest_corr = car_corr
        else:
            vector = self.dest_corr - self.position
            e = vector / np.linalg.norm(vector + 1e-10)
            self.position = self.position + e * self.speed
            #print("car_pos=", self.position)
    
    def count(self): #次の重心についてしまったけどドローンが全員帰ってきてないときは待つ
        count_ = sum([1 for drone in droneSet if drone.working])
        if count_ == 0:
            print("All On the car")
        print("DroneNum=",2- count_)
        return count_
    
    def

# %% [markdown]
# # 以下、シミュレーションのひな型

# %%
routeList = [0,3,2,1]
centroids = [2]
trajectory = np.zeros((0,4))
car_trajectory = np.zeros((0,2))
car_1 = car(1, 0, 0.07,  routeList, centroids)
drone_1 = drone(1, 0, 0.27, 0, 2)
drone_2 = drone(1, 0, 0.27, 0, 1)

for time in range(20):
    if time == 0:
       pass
    else:
        car_1.procede()
        car_corr = car_1.position
        drone_1.action() 
        drone_2.action() 
    #print(drone_1.e)
    a = (np.array([drone_1.position, drone_2.position]).flatten())
    trajectory = np.append(trajectory, np.array([a]), axis = 0)
    car_trajectory = np.append(car_trajectory, np.array([car_1.position]), axis = 0)
    print()
print(car_trajectory)
plt.plot(trajectory[:,0],trajectory[:,1],c = "b")
plt.plot(trajectory[:,2],trajectory[:,3],c = "green")
plt.plot(car_trajectory[:,0],car_trajectory[:,1], c = "red")
plt.xlim([-0.2,1]), plt.ylim([0,1])
#plt.show()
# Out:
# car_corr= [0.   0.07]
# drone_pos= [0.19091883 0.19091883]
# car_corr= [0.   0.07]
# drone_pos= [0.27 0.  ]
#
# car_corr= [0.   0.14]
# drone_pos= [0.38183766 0.38183766]
# car_corr= [0.   0.14]
# drone_pos= [0.54 0.  ]
#
# car_corr= [0.   0.21]
# drone_pos= [0.57275649 0.57275649]
# car_corr= [0.   0.21]
# drone_pos= [0.81 0.  ]
#
# car_corr= [0.   0.28]
# drone_pos= [0.76367532 0.76367532]
# car_corr= [0.   0.28]
# drone_pos= [1 0]
# arrived
# destination= [1 0]
#
# car_corr= [0.   0.35]
# drone_pos= [0.95459415 0.95459415]
# car_corr= [0.   0.35]
# drone_pos= [0.74515824 0.08919461]
#
# car_corr= [0.   0.42]
# drone_pos= [1 1]
# arrived
# destination= [1 1]
# car_corr= [0.   0.42]
# drone_pos= [0.49838293 0.19874799]
#
# car_corr= [0.   0.49]
# drone_pos= [0.75947443 0.87733196]
# car_corr= [0.   0.49]
# drone_pos= [0.26527031 0.33497761]
#
# car_corr= [0.   0.56]
# drone_pos= [0.51034676 0.7732387 ]
# car_corr= [0.   0.56]
# drone_pos= [0.05937161 0.5096365 ]
#
# car_corr= [0.   0.63]
# drone_pos= [0.25039171 0.70027728]
# car_corr= [0.   0.63]
# drone_pos= [0.   0.63]
# arrived
# a
# destination= [0.   0.63]
#
# car_corr= [0.  0.7]
# drone_pos= [0.  0.7]
# arrived
# a
# destination= [0.  0.7]
#
#
#
#
#
#
#
#
#
#
# [[0.   0.  ]
#  [0.   0.07]
#  [0.   0.14]
#  [0.   0.21]
#  [0.   0.28]
#  [0.   0.35]
#  [0.   0.42]
#  [0.   0.49]
#  [0.   0.56]
#  [0.   0.63]
#  [0.   0.7 ]
#  [0.   0.77]
#  [0.   0.84]
#  [0.   0.91]
#  [0.   0.98]
#  [0.   1.  ]
#  [0.   0.98]
#  [0.   1.  ]
#  [0.   0.98]
#  [0.   1.  ]]

# %%
droneSet = [drone(1, 0, 0.27, 0, 2), drone(1, 0, 0.27, 0, 1)]
len(droneSet)

a = (np.array([drone.position for drone in droneSet]).flatten())
routeList = [0,3,2,1]
centroids = [2]
trajectory = np.zeros((0,4))
car_trajectory = np.zeros((0,2))
car_1 = car(1, 0, 0.07,  routeList, centroids)

for time in range(20):
    print("time=", time)
    car_1.count()
    if time == 0:
       pass
    else:
        car_1.procede()
        car_corr = car_1.position
        [drone.action() for drone in droneSet]
    #print(drone_1.e)
    a = (np.array([droneSet[i].position for i in range(2)]).flatten())
    trajectory = np.append(trajectory, np.array([a]), axis = 0)
    car_trajectory = np.append(car_trajectory, np.array([car_1.position]), axis = 0)
    print()
#print(car_trajectory)
plt.plot(trajectory[:,0],trajectory[:,1],c = "b")
plt.plot(trajectory[:,2],trajectory[:,3],c = "green")
plt.plot(car_trajectory[:,0],car_trajectory[:,1], c = "red")
plt.xlim([-0.2,1.1]), plt.ylim([-0.2,1.1])
plt.show()
# Out:
# time= 0
# DroneNum= 0
#
# time= 1
# DroneNum= 0
# car_corr= [0.   0.07]
# drone_pos= [0.19091883 0.19091883]
# car_corr= [0.   0.07]
# drone_pos= [0.27 0.  ]
#
# time= 2
# DroneNum= 0
# car_corr= [0.   0.14]
# drone_pos= [0.38183766 0.38183766]
# car_corr= [0.   0.14]
# drone_pos= [0.54 0.  ]
#
# time= 3
# DroneNum= 0
# car_corr= [0.   0.21]
# drone_pos= [0.57275649 0.57275649]
# car_corr= [0.   0.21]
# drone_pos= [0.81 0.  ]
#
# time= 4
# DroneNum= 0
# car_corr= [0.   0.28]
# drone_pos= [0.76367532 0.76367532]
# car_corr= [0.   0.28]
# drone_pos= [1 0]
# arrived
# destination= [1 0]
#
# time= 5
# DroneNum= 0
# car_corr= [0.   0.35]
# drone_pos= [0.95459415 0.95459415]
# car_corr= [0.   0.35]
# drone_pos= [0.74515824 0.08919461]
#
# time= 6
# DroneNum= 0
# car_corr= [0.   0.42]
# drone_pos= [1 1]
# arrived
# destination= [1 1]
# car_corr= [0.   0.42]
# drone_pos= [0.49838293 0.19874799]
#
# time= 7
# DroneNum= 0
# car_corr= [0.   0.49]
# drone_pos= [0.75947443 0.87733196]
# car_corr= [0.   0.49]
# drone_pos= [0.26527031 0.33497761]
#
# time= 8
# DroneNum= 0
# car_corr= [0.   0.56]
# drone_pos= [0.51034676 0.7732387 ]
# car_corr= [0.   0.56]
# drone_pos= [0.05937161 0.5096365 ]
#
# time= 9
# DroneNum= 0
# car_corr= [0.   0.63]
# drone_pos= [0.25039171 0.70027728]
# car_corr= [0.   0.63]
# drone_pos= [0.   0.63]
# arrived
# a
# destination= [0.   0.63]
#
# time= 10
# DroneNum= 1
# car_corr= [0.  0.7]
# drone_pos= [0.  0.7]
# arrived
# a
# destination= [0.  0.7]
#
# time= 11
# All On the car
# DroneNum= 2
#
# time= 12
# All On the car
# DroneNum= 2
#
# time= 13
# All On the car
# DroneNum= 2
#
# time= 14
# All On the car
# DroneNum= 2
#
# time= 15
# All On the car
# DroneNum= 2
#
# time= 16
# All On the car
# DroneNum= 2
#
# time= 17
# All On the car
# DroneNum= 2
#
# time= 18
# All On the car
# DroneNum= 2
#
# time= 19
# All On the car
# DroneNum= 2

# %% [markdown]
# # ここで今一度グラフのインポート

# %%
import pandas as pd
import pickle
def pickle_load(path):
    with open(path, mode='rb') as f:
        data = pickle.load(f)
        return data

df = pd.read_csv("networkData.csv")
pos = pickle_load("positionDict.pickle")
df1, df2, df3 = df["START_NODE"], df["END_NODE"], df["LENGTH"]
#range(len(list(pos)))
df2 = df2.replace(list(pos),range(len(list(pos))))
df1 = df1.replace(list(pos),range(len(list(pos))))
edges = np.concatenate([np.array([df1]), np.array([df2]), np.array([df3])], axis = 0).T
coords = df.values[:,1:3]
posRename = {}
# ndarrayの情報を「頂点:(x,y)」という値(辞書)に変換する
for i in range(len(coords) ):
    if i != 0 and (coords[i][0], coords[i][1]) == (coords[i-1][0], coords[i-1][1]):
        pass
    else:
        posRename[int(df1[i])] = (coords[i][0], coords[i][1])
np.savetxt("edge_weight.txt", edges, fmt = '%d')
G2 = nx.read_weighted_edgelist("edge_weight.txt", nodetype = int)
nx.draw(G2, posRename, node_size = 1, node_color = "b", edge_color="gray", width=1)
plt.show()
# Out:
# C:\Users\akihiro\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# C:\Users\akihiro\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:522: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cb.is_string_like(edge_color) \
# C:\Users\akihiro\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:543: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if cb.is_string_like(edge_color) or len(edge_color) == 1:
# C:\Users\akihiro\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# C:\Users\akihiro\Anaconda3\lib\site-packages\matplotlib\__init__.py:911: MatplotlibDeprecationWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   mplDeprecation)
# C:\Users\akihiro\Anaconda3\lib\site-packages\matplotlib\rcsetup.py:156: MatplotlibDeprecationWarning: axes.hold is deprecated, will be removed in 3.0
#   mplDeprecation)
